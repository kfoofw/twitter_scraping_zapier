# %%
import string
import pandas as pd
import numpy as np
from polyglot.detect import Detector
import re
import warnings
warnings.filterwarnings(action = "ignore")
import icu
import nltk

# %% [markdown]
# ## Punctuation, URL and text removal/replacements but without stopwords removal

# %%
import re
import string
from nltk.tokenize import word_tokenize

# Function for cleaning text by removing punctuation only
def clean_text(text):
    # remove all urls as identified by "http" and "www". 
    # "\S+" removes all non-whitespace characters as part of the url until the end of url as defined by whitespace
    # https://stackoverflow.com/questions/24399820/expression-to-remove-url-links-from-twitter-tweet/24399874
    regex_url = re.compile(r"http\S+"+"|"
                           +"www\S+"+"|"
                          +"\S+\.com\S+")
    dirty_text = regex_url.sub(" ", str(text).lower())
    
    # Replace "i'm" with "i am"
    regex_im = re.compile(r"i'm ")
    dirty_text = regex_im.sub("i am ", str(dirty_text))
    
    # Replace "i'll" with "i will"
    regex_im = re.compile(r"i'll ")
    dirty_text = regex_im.sub("i will ", str(dirty_text))
    
    # Replace "let's" with "let us"
    regex_lets = re.compile(r"let's ")
    dirty_text = regex_lets.sub("let us ", str(dirty_text))
    
    # Replace "it's" with "it is"
    regex_its = re.compile(r"it's ")
    dirty_text = regex_its.sub("it is ", str(dirty_text))
    
    # Replace "there's" with "there is"
    regex_theres = re.compile(r"there's ")
    dirty_text = regex_theres.sub("there is ", str(dirty_text))
    
    # Replace "don't" with "do not"
    regex_dont = re.compile(r"don't ")
    dirty_text = regex_dont.sub("do not ", str(dirty_text))
    
    # Replace digits and digits with one instance of comma formatting
    regex_digits = re.compile(r"\d*[,]+\d*[+]?"+"|"+
                              "\d+")
    dirty_text = regex_digits.sub(" ", str(dirty_text))
    
    # Replace twitter tags
    regex_twittertags = re.compile(r"#\S+")
    dirty_text = regex_twittertags.sub(" ", str(dirty_text))
    
     # Replace twitter handles
    regex_twitterhandles = re.compile(r"@\S+")
    dirty_text = regex_twitterhandles.sub(" ", str(dirty_text))
    
    # remove punc except new lines "\n"
    regex_punct = re.compile('['+ re.escape(string.punctuation) + '\\r\\t]')
    nopunct = regex_punct.sub(" ", str(dirty_text))
    
    tokens = word_tokenize(nopunct.lower())
    
    return tokens

# %% [markdown]
# ## Text Cleaning Function

# %%
from nltk.corpus import stopwords
#nltk.download('averaged_perceptron_tagger')

#get english stopwords
en_stopwords = set(stopwords.words('english'))
# add "zapier" and "..." to stopwords
en_stopwords.add("zapier")
en_stopwords.add("…")

stop_words_to_put_back = ["after", "any", "both", "between", "do","once","these","off",
                          #"on", "to", "and", "with","you",
                          "through","what", "when", "while","which", "where"]
for i in stop_words_to_put_back:
    en_stopwords.remove(i)

# Create function for filtering dataframe
def rightTypes(ngram):
    # remove stop words
    for word in ngram:
        if word in en_stopwords:
            return False
    
    # no conjunctions
    non_acceptable_types = ('CONJ')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in non_acceptable_types or tags[1][1] in non_acceptable_types:
        return False
    else:
        return True

# %% [markdown]
# ## Function for bigrams comparison table across different methods

# %%
def create_bigrams_compare(dat, min_filter = 10, table_rows = 50): 

    # Count words in text. Preprocessing for filtering out text of word count = 1 so language detector can work
    dat["num_words"] = dat["text"].apply(lambda x: len(re.findall(r'\w+', str(x))))

    # Drop all rows where text is only 1 word
    dat = dat[dat["num_words"] >1].reset_index(drop = True)
    
    #function to remove non-ascii characters (otherwise it will throw error in langauge detection)
    def removeNonAscii(s): return "".join(i for i in s if ord(i)<128)
    
    dat["text"] = dat["text"].map(removeNonAscii)

    # Detect language
    from polyglot.detect import Detector
    dat["detector"] = dat["text"].apply(lambda x: Detector(x, quiet = True))

    import icu
    dat["language"] = dat["detector"].apply(lambda x: icu.Locale.getDisplayName(x.language.locale))
    dat["confidence"] = dat["detector"].apply(lambda x: x.language.confidence)

    # Filter for only english tweets
    dat = dat[dat["language"] == "English"].reset_index(drop = True)

    # Combine all list of tokens into one list, but segment between with new line escape "\n" to separate out tweet 
    # (otherwise introduce false signal between last word of each tweet and first word of the next tweet for bigrams)
    list_str = list(dat["text"])
    list_str_tot = "\n".join(list_str)

    # Perform cleaning function
    clean_tokens = clean_text(list_str_tot)
    
    import nltk

    # Bigrams finder
    bigrams = nltk.collocations.BigramAssocMeasures()
    bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(clean_tokens)

    # Frequency
    bigram_freq = bigramFinder.ngram_fd.items()
    bigramFreqTable = pd.DataFrame(list(bigram_freq), columns = ["bigram", "freq"]).sort_values(by="freq", ascending = False)

    clean_bigramFreqTable = bigramFreqTable[bigramFreqTable["bigram"].map(lambda x: rightTypes(x))].reset_index(drop = True)

    # PMI
    bigrams = nltk.collocations.BigramAssocMeasures()
    bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(clean_tokens)

    # Filter out bigram frequencies
    bigramFinder.apply_freq_filter(min_filter)

    bigramPMITable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['bigram','PMI']).sort_values(by='PMI', ascending=False)

    clean_bigramPMITable = bigramPMITable[bigramPMITable["bigram"].map(lambda x: rightTypes(x))].reset_index(drop = True)

    # T-test
    bigramTtestTable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.student_t)), columns=['bigram','t']).sort_values(by='t', ascending=False)

    clean_bigramTtestTable = bigramTtestTable[bigramTtestTable["bigram"].map(lambda x: rightTypes(x))].reset_index(drop = True)

    # Chi Square
    bigramChiTable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.chi_sq)), columns=['bigram','chi-sq']).sort_values(by='chi-sq', ascending=False)

    clean_bigramChiTable = bigramChiTable[bigramChiTable["bigram"].map(lambda x: rightTypes(x))].reset_index(drop = True)

    # Likelihood Ratio
    bigramLikeTable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.likelihood_ratio)), columns=['bigram','likelihood ratio']).sort_values(by='likelihood ratio', ascending=False)

    clean_bigramLikeTable = bigramLikeTable[bigramLikeTable["bigram"].map(lambda x: rightTypes(x))].reset_index(drop = True)

    # Bigrams Comparison
    bigramsCompare = pd.DataFrame([clean_bigramFreqTable["bigram"][:table_rows].values, clean_bigramPMITable["bigram"][:table_rows].values, clean_bigramTtestTable["bigram"][:table_rows].values, clean_bigramChiTable["bigram"][:table_rows].values, clean_bigramLikeTable["bigram"][:table_rows].values]).T

    bigramsCompare.columns = ['Frequency', 'PMI', 'T-test', 'Chi-Sq Test', 'Likelihood Ratio Test']

    return bigramsCompare

# %% [markdown]
# # Read in all the data from all years

# %%
dat_2019 = pd.read_csv("./output_scrape/output_2019.csv")
dat_2018 = pd.read_csv("./output_scrape/output_2018.csv")
dat_2017 = pd.read_csv("./output_scrape/output_2017.csv")
dat_2016 = pd.read_csv("./output_scrape/output_2016.csv")

# %%
bigrams_compare_2019 = create_bigrams_compare(dat_2019, table_rows = 200)
bigrams_compare_2018 = create_bigrams_compare(dat_2018, table_rows = 200)
bigrams_compare_2017 = create_bigrams_compare(dat_2017, table_rows = 200)
bigrams_compare_2016 = create_bigrams_compare(dat_2016, table_rows = 200)
# Out:
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# ...
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.

# %%
bigrams_compare_2016
# Out:
#                    Frequency                             PMI  \
# 0         (launches, digest)        (numerous, improvements)
# 1          (messages, where)                  (derek, bolen)
# 2                 (app, new)                    (dated, sep)
# 3          (powerful, tools)                (greatest, hits)
# 4         (marketing, stack)                      (sap, jam)
# 5             (stress, free)              (paper, notebooks)
# 6                (do, lists)               (maximum, volume)
# 7              (lists, work)                  (volume, flex)
# 8        (chrome, extension)             (background, noise)
# 9             (remote, work)             (curation, machine)
# 10         (ultimate, guide)                     (tax, prep)
# 11               (web, apps)   (activecampaign, pushoverand)
# 12              (stack, via)         (wunderlist, docparser)
# 13            (life, easier)              (keystone, habits)
# 14        (marketing, tools)              (conscious, style)
# 15               (easier, w)           (downtime, dashboard)
# 16   (marketing, automation)                  (third, party)
# 17         (remote, welcome)                (reader, survey)
# 18        (engineer, remote)            (airtable, intercom)
# 19          (new, favourite)                     (law, firm)
# 20             (great, tips)                    (dick, dale)
# 21            (time, saving)               (elses, schedule)
# 22           (social, media)                (someone, elses)
# 23        (feeling, awkward)     (insightful, communication)
# 24        (inbound, unboxed)            (shareable, summary)
# 25       (introducing, push)               (shared, agendas)
# 26                (make, us)       (infusionsoft, insightly)
# 27         (affects, others)                (startup, costs)
# 28                (us, work)                   (song, sound)
# 29            (work, harder)             (tactful, language)
# ..                       ...                             ...
# 170          (mind, sending)                     (shoot, us)
# 171          (reading, list)               (kayako, andmore)
# 172              (email, us)                     (easier, w)
# 173          (foster, talks)                  (backed, ways)
# 174            (sell, stuff)             (button, workflows)
# 175       (new, integration)                  (best, places)
# 176           (cheat, sheet)               (messages, where)
# 177              (done, via)                   (help, scout)
# 178           (via, knowing)                   (top, proven)
# 179         (app, workflows)                  (stress, free)
# 180            (via, thanks)                 (online, store)
# 181      (product, marketer)                      (drop, us)
# 182             (store, via)                (dribbble, post)
# 183            (guest, post)                (google, sheets)
# 184        (small, business)              (basecamp, kayako)
# 185           (style, guide)               (articles, would)
# 186              (team, via)          (simple, alternatives)
# 187            (apps, using)                    (what, muli)
# 188         (someone, elses)                   (guest, post)
# 189              (best, one)                  (zero, manage)
# 190            (plans, what)                   (dream, team)
# 191      (favourite, social)                     (big, list)
# 192             (day, great)                 (onenote, take)
# 193       (conscious, style)  (automation, technologyadvice)
# 194      (tactful, language)                 (five, updates)
# 195            (tools, like)                   (easy, steps)
# 196      (collaborate, plan)          (professional, social)
# 197          (anyone, using)              (google, calendar)
# 198         (via, marketing)                   (multi, step)
# 199            (read, books)                    (every, day)
#
#                       T-test                    Chi-Sq Test  \
# 0         (launches, digest)                 (derek, bolen)
# 1          (messages, where)       (numerous, improvements)
# 2                 (app, new)                   (dick, dale)
# 3          (powerful, tools)            (cutting, expenses)
# 4         (marketing, stack)             (inbound, unboxed)
# 5             (stress, free)              (maximum, volume)
# 6                (do, lists)                 (volume, flex)
# 7              (lists, work)               (cross, posting)
# 8        (chrome, extension)             (feeling, awkward)
# 9             (remote, work)            (background, noise)
# 10         (ultimate, guide)                 (wade, foster)
# 11               (web, apps)            (chrome, extension)
# 12              (stack, via)              (messages, where)
# 13            (life, easier)             (conscious, style)
# 14               (easier, w)            (curation, machine)
# 15        (marketing, tools)                   (dated, sep)
# 16   (marketing, automation)               (greatest, hits)
# 17         (remote, welcome)             (fastest, growing)
# 18        (engineer, remote)                     (sap, jam)
# 19          (new, favourite)                    (tax, prep)
# 20             (great, tips)               (while, cutting)
# 21            (time, saving)             (paper, notebooks)
# 22           (social, media)        (wunderlist, docparser)
# 23        (inbound, unboxed)              (shared, agendas)
# 24        (feeling, awkward)  (activecampaign, pushoverand)
# 25       (introducing, push)             (launches, digest)
# 26         (affects, others)                 (stress, free)
# 27            (work, harder)               (reader, survey)
# 28                (make, us)                 (life, easier)
# 29           (work, affects)              (affects, others)
# ..                       ...                            ...
# 170              (email, us)                 (these, smart)
# 171               (via, hey)                (actually, get)
# 172           (style, guide)                 (sound, cloud)
# 173            (guest, post)                 (trello, uses)
# 174        (small, business)                    (year, end)
# 175         (app, workflows)                 (work, harder)
# 176           (via, knowing)                     (app, new)
# 177              (work, via)          (project, management)
# 178       (conscious, style)                (boring, tasks)
# 179         (someone, elses)          (communicate, better)
# 180      (tactful, language)             (google, calendar)
# 181            (read, books)                   (every, day)
# 182      (collaborate, plan)                 (uses, trello)
# 183            (plans, what)           (workflows, newapps)
# 184      (favourite, social)            (welcome, comments)
# 185          (anyone, using)                  (time, daily)
# 186             (day, great)                 (best, places)
# 187              (best, one)               (instagram, app)
# 188        (elses, schedule)                 (style, guide)
# 189         (startup, costs)                 (zero, manage)
# 190    (efficient, meetings)             (top, influencers)
# 191       (leadboxer, works)                 (closer, look)
# 192      (content, curation)                 (senior, data)
# 193           (feed, called)             (motivation, even)
# 194          (product, hunt)                  (great, tips)
# 195         (dribbble, post)                   (prep, ways)
# 196            (easy, steps)            (sharedesk, google)
# 197            (first, user)                  (blog, posts)
# 198        (online, writing)                  (recipes, rt)
# 199              (done, via)             (google, tasksand)
#
#          Likelihood Ratio Test
# 0            (messages, where)
# 1           (launches, digest)
# 2               (stress, free)
# 3          (chrome, extension)
# 4            (powerful, tools)
# 5           (marketing, stack)
# 6                  (do, lists)
# 7                (lists, work)
# 8            (ultimate, guide)
# 9               (life, easier)
# 10                  (app, new)
# 11                 (easier, w)
# 12          (inbound, unboxed)
# 13          (feeling, awkward)
# 14             (social, media)
# 15                 (web, apps)
# 16           (remote, welcome)
# 17         (cutting, expenses)
# 18           (affects, others)
# 19            (new, favourite)
# 20              (remote, work)
# 21            (while, cutting)
# 22            (cross, posting)
# 23                 (week, six)
# 24              (time, saving)
# 25              (wade, foster)
# 26       (scheduling, methods)
# 27          (user, engagement)
# 28                 (rss, feed)
# 29              (six, updates)
# ..                         ...
# 170             (recent, blog)
# 171          (review, pricing)
# 172        (pricing, features)
# 173            (product, hunt)
# 174              (these, apps)
# 175          (millionth, user)
# 176               (dated, sep)
# 177         (custom, mixpanel)
# 178            (stuff, online)
# 179          (building, games)
# 180               (feel, like)
# 181   (numerous, improvements)
# 182           (greatest, hits)
# 183    (alternatives, zapbook)
# 184              (guest, post)
# 185               (head, show)
# 186  (infusionsoft, insightly)
# 187             (feed, called)
# 188        (gtd, alternatives)
# 189         (paper, notebooks)
# 190       (microsoft, onenote)
# 191             (smart, email)
# 192               (prep, ways)
# 193         (keystone, habits)
# 194             (third, party)
# 195       (docparser, andmore)
# 196            (writing, apps)
# 197           (dribbble, post)
# 198       (shareable, summary)
# 199             (senior, data)
#
# [200 rows x 5 columns]

# %%
bigrams_compare_2017
# Out:
#                    Frequency                            PMI  \
# 0             (life, easier)   (activedemand, supercharges)
# 1           (team, accounts)          (endurance, athletes)
# 2              (month, team)          (employer, spotlight)
# 3          (launches, month)              (esight, eyewear)
# 4                (easier, w)              (fitting, square)
# 5             (these, tools)                 (square, pegs)
# 6                 (w, these)          (western, hemisphere)
# 7           (app, workflows)                (hole, fillers)
# 8                (lead, gen)                     (mon, jun)
# 9                (rss, feed)                (intense, pace)
# 10               (lead, ads)           (september, edition)
# 11              (gen, forms)                 (craft, clubs)
# 12          (facebook, lead)                 (webcam, mute)
# 13            (remote, work)               (award, winning)
# 14             (shave, club)  (procrastinate, productively)
# 15          (monthly, shave)           (imposter, syndrome)
# 16              (club, uses)              (silicon, valley)
# 17            (wade, foster)               (adam, duvander)
# 18          (email, address)               (micro, moments)
# 19             (pulled, off)             (inspect, element)
# 20          (done, approach)             (macro, scheduler)
# 21         (ultimate, guide)              (billion, dollar)
# 22       (new, integrations)                  (mike, knoop)
# 23             (these, apps)             (paper, notebooks)
# 24   (integrations, powered)               (learndash, lms)
# 25           (social, media)         (unrelated, interests)
# 26               (web, apps)           (afternoon, routine)
# 27              (any, email)       (avoiding, distractions)
# 28              (lead, data)               (pioneer, views)
# 29               (tips, via)            (pair, programming)
# ..                       ...                            ...
# 170   (automate, operations)             (public, speaking)
# 171         (work, survival)      (enterprise, venturebeat)
# 172         (free, download)               (internet, mark)
# 173       (business, owners)                (influence, co)
# 174       (easy, automation)     (unlimited, possibilities)
# 175       (news, recruiters)                  (stay, tuned)
# 176   (automated, workflows)                (net, promoter)
# 177           (time, saving)                     (g, suite)
# 178          (minute, guide)                    (bay, area)
# 179         (bringing, easy)              (startup, gained)
# 180               (hr, folk)              (dollar, startup)
# 181               (news, hr)          (christopher, peters)
# 182    (automatically, send)           (connecting, differ)
# 183            (free, ebook)       (infrastructure, devops)
# 184       (task, management)        (location, independent)
# 185     (workflow, airtable)                (class, easily)
# 186    (automation, recipes)                (avoid, saying)
# 187           (success, via)         (increase, efficiency)
# 188       (software, trends)             (learning, styles)
# 189           (three, years)              (busywork, hello)
# 190              (big, list)                    (gained, k)
# 191             (super, ama)              (promoter, score)
# 192             (any, plans)                     (mar, ama)
# 193             (feel, free)              (foundr, podcast)
# 194             (via, tools)              (less, stressful)
# 195          (new, platform)         (difficult, decisions)
# 196             (apps, like)                   (win, deals)
# 197         (work, remotely)               (cross, posting)
# 198             (read, blog)                   (public, wi)
# 199             (need, less)             (different, parts)
#
#                       T-test                   Chi-Sq Test  \
# 0             (life, easier)         (endurance, athletes)
# 1           (team, accounts)             (esight, eyewear)
# 2          (launches, month)             (fitting, square)
# 3              (month, team)             (silicon, valley)
# 4                (easier, w)                (square, pegs)
# 5             (these, tools)                 (shave, club)
# 6                 (w, these)               (net, promoter)
# 7                (lead, gen)               (brute, forced)
# 8           (app, workflows)         (christopher, peters)
# 9                (rss, feed)          (imposter, syndrome)
# 10               (lead, ads)              (boot, strapped)
# 11              (gen, forms)                (wade, foster)
# 12          (facebook, lead)         (western, hemisphere)
# 13             (shave, club)              (san, francisco)
# 14          (monthly, shave)              (monthly, shave)
# 15              (club, uses)        (detecting, corporate)
# 16            (remote, work)  (activedemand, supercharges)
# 17            (wade, foster)          (september, edition)
# 18          (email, address)                      (wi, fi)
# 19             (pulled, off)             (promoter, score)
# 20          (done, approach)        (unrelated, interests)
# 21         (ultimate, guide)                   (bay, area)
# 22       (new, integrations)                    (mon, jun)
# 23           (social, media)       (discusses, defaulting)
# 24   (integrations, powered)          (corporate, signups)
# 25               (web, apps)           (evening, routines)
# 26             (these, apps)               (intense, pace)
# 27          (google, sheets)           (coworking, spaces)
# 28              (lead, data)           (cutting, expenses)
# 29              (any, email)         (employer, spotlight)
# ..                       ...                           ...
# 170         (bringing, easy)                    (w, these)
# 171               (news, hr)         (developer, platform)
# 172          (minute, guide)               (saas, pioneer)
# 173           (time, saving)               (card, scanner)
# 174   (automated, workflows)              (newly, updated)
# 175        (remote, product)              (side, projects)
# 176            (free, ebook)           (centric, services)
# 177       (task, management)                (v, learndash)
# 178     (workflow, airtable)               (agile, method)
# 179    (automation, recipes)               (francisco, ca)
# 180           (three, years)              (thatwhy, spiro)
# 181       (software, trends)         (amplified, learning)
# 182             (super, ama)               (class, easily)
# 183              (big, list)           (background, noise)
# 184    (automatically, send)            (devops, engineer)
# 185             (any, plans)           (slackpass, medium)
# 186             (feel, free)              (email, address)
# 187        (teams, automate)           (foster, discusses)
# 188              (new, free)            (nonprofit, sends)
# 189             (need, less)         (aweber, postplanner)
# 190         (work, remotely)                 (zirch, save)
# 191            (less, noise)            (software, trends)
# 192    (distributed, design)                 (non, profit)
# 193           (success, via)             (knowledge, base)
# 194             (read, blog)                 (two, factor)
# 195               (k, month)              (avoid, burnout)
# 196          (agency, zirch)                (note, taking)
# 197          (new, platform)                    (add, ons)
# 198      (marketing, agency)          (connecting, differ)
# 199            (recipes, rt)         (calendars, contacts)
#
#           Likelihood Ratio Test
# 0                (life, easier)
# 1             (launches, month)
# 2              (team, accounts)
# 3                 (month, team)
# 4                   (easier, w)
# 5                   (rss, feed)
# 6                 (shave, club)
# 7                   (lead, gen)
# 8              (monthly, shave)
# 9                (wade, foster)
# 10                   (w, these)
# 11                 (club, uses)
# 12                (pulled, off)
# 13                 (gen, forms)
# 14                  (lead, ads)
# 15               (these, tools)
# 16        (christopher, peters)
# 17              (social, media)
# 18             (done, approach)
# 19              (net, promoter)
# 20             (app, workflows)
# 21            (promoter, score)
# 22            (ultimate, guide)
# 23                 (muli, step)
# 24             (score, matters)
# 25             (email, address)
# 26             (facebook, lead)
# 27      (integrations, powered)
# 28                  (bay, area)
# 29             (cross, posting)
# ..                          ...
# 170             (stay, focused)
# 171        (integrate, hubspot)
# 172        (solvers, featuring)
# 173      (product, engineering)
# 174             (uses, shopify)
# 175               (cli, allows)
# 176                   (gon, na)
# 177    (infrastructure, devops)
# 178         (skillshare, class)
# 179            (work, survival)
# 180      (unrelated, interests)
# 181           (science, backed)
# 182             (avoid, saying)
# 183         (deliver, complete)
# 184                 (team, via)
# 185         (engineering, team)
# 186         (foster, discusses)
# 187        (leverage, assembla)
# 188           (ambient, office)
# 189  (limitless, possibilities)
# 190            (human, phrases)
# 191       (calendars, contacts)
# 192              (seo, manager)
# 193        (complete, internet)
# 194          (devops, engineer)
# 195                 (rd, party)
# 196              (note, taking)
# 197        (upgrade, limitless)
# 198             (boring, tasks)
# 199            (free, download)
#
# [200 rows x 5 columns]

# %%
bigrams_compare_2018
# Out:
#                    Frequency                           PMI  \
# 0         (new, integration)        (warehouse, architect)
# 1         (marketing, tools)                      (wi, fi)
# 2           (revenue, leaks)        (consultant, converts)
# 3         (biggest, revenue)           (emily, breuninger)
# 4            (live, without)         (translate, indexing)
# 5               (leaks, via)                (spiro, loves)
# 6        (app, integrations)            (rescue, shelters)
# 7           (google, sheets)             (cognitive, bias)
# 8       (million, customers)         (keyword, extraction)
# 9            (social, media)                 (neil, swear)
# 10        (segment, workato)                (nomad, emily)
# 11         (unicorn, status)              (san, francisco)
# 12        (snaplogic, which)            (realtor, reduces)
# 13   (business, integration)              (dollar, flight)
# 14           (status, first)        (bigcommerce, magento)
# 15        (achieve, unicorn)            (mlsp, funnelizer)
# 16          (many, startups)           (coworking, spaces)
# 17          (these, leading)  (activedemand, supercharges)
# 18       (leading, business)         (western, hemisphere)
# 19   (integration, services)                 (dog, rescue)
# 20              (work, flow)           (indexing, secrets)
# 21             (first, read)    (accountants, bookkeepers)
# 22       (flow, automations)    (entrepreneur, prototyped)
# 23   (saleswings, unleashes)            (scrum, framework)
# 24     (unleashes, powerful)                     (gon, na)
# 25         (marketing, work)                     (wan, na)
# 26         (powerful, sales)                   (boss, mom)
# 27              (save, time)                 (shave, club)
# 28       (customer, support)         (financial, planners)
# 29                 (let, us)               (realty, trust)
# ..                       ...                           ...
# 170            (when, cross)  (personalized, notification)
# 171          (life, balance)             (evernote, named)
# 172         (instagram, app)         (podcast, promotions)
# 173             (best, apps)                  (mind, maps)
# 174         (post, pictures)            (lessons, learned)
# 175           (de, location)           (buffer, treehouse)
# 176      (integrations, via)                   (kick, off)
# 177              (find, any)              (hangouts, chat)
# 178           (get, started)           (automator, review)
# 179          (google, drive)                (extra, value)
# 180            (these, apps)               (seo, strategy)
# 181       (balance, through)                   (rss, feed)
# 182             (feel, free)              (trends, report)
# 183    (through, automating)              (fav, following)
# 184             (gain, life)          (security, engineer)
# 185      (automating, areas)             (zendesk, ticket)
# 186               (join, us)      (creating, certificates)
# 187             (need, help)                 (sparks, job)
# 188        (companies, like)           (forward, hangouts)
# 189      (projects, forward)             (unicorn, status)
# 190              (new, year)                  (affects, b)
# 191             (best, free)                  (rss, feeds)
# 192            (every, week)                 (kind, words)
# 193          (removed, when)             (science, behind)
# 194               (drop, us)             (merge, multiple)
# 195             (any, email)      (automated, handwritten)
# 196        (wordpress, site)             (core, developer)
# 197               (what, do)           (finding, creative)
# 198          (when, hashing)              (event, campout)
# 199             (team, chat)                        (e, g)
#
#                       T-test                   Chi-Sq Test  \
# 0         (new, integration)            (mlsp, funnelizer)
# 1         (marketing, tools)                      (wi, fi)
# 2           (revenue, leaks)       (saleswings, unleashes)
# 3         (biggest, revenue)              (akun, bersihin)
# 4            (live, without)               (benerin, akun)
# 5               (leaks, via)                (jasa, upfoll)
# 6           (google, sheets)                   (axis, lms)
# 7        (app, integrations)          (uncanny, automator)
# 8       (million, customers)              (revenue, leaks)
# 9            (social, media)        (warehouse, architect)
# 10        (segment, workato)            (segment, workato)
# 11         (unicorn, status)            (achieve, unicorn)
# 12        (snaplogic, which)     (meaningful, experiences)
# 13           (status, first)  (activedemand, supercharges)
# 14        (achieve, unicorn)                (wade, foster)
# 15          (many, startups)        (consultant, converts)
# 16          (these, leading)         (western, hemisphere)
# 17       (leading, business)              (san, francisco)
# 18             (first, read)            (remember, weemss)
# 19              (work, flow)           (emily, breuninger)
# 20   (saleswings, unleashes)         (translate, indexing)
# 21     (unleashes, powerful)            (biggest, revenue)
# 22         (powerful, sales)               (coupon, codes)
# 23       (flow, automations)              (dollar, flight)
# 24   (integration, services)             (cognitive, bias)
# 25         (marketing, work)                 (neil, swear)
# 26   (business, integration)         (keyword, extraction)
# 27              (save, time)          (weekly, analytical)
# 28       (customer, support)                (spiro, loves)
# 29                 (let, us)         (analytical, reports)
# ..                       ...                           ...
# 170           (de, location)    (limitless, possibilities)
# 171        (something, like)                (slash, admin)
# 172               (new, app)       (affiliates, slackpass)
# 173           (get, started)                  (plus, plus)
# 174      (automating, areas)             (process, street)
# 175             (gain, life)           (automator, review)
# 176       (balance, through)          (security, engineer)
# 177             (feel, free)           (writing, mistakes)
# 178          (google, drive)          (creative, thinkers)
# 179              (find, any)              (user, unfollow)
# 180    (through, automating)        (monitor, competitors)
# 181               (join, us)                 (first, read)
# 182      (projects, forward)              (photo, editors)
# 183        (companies, like)           (leading, business)
# 184            (every, week)     (versatility, connecting)
# 185     (wondering, whether)                  (gain, life)
# 186          (when, hashing)                  (leave, san)
# 187        (wordpress, site)                  (bot, pairs)
# 188          (removed, when)              (test, mentions)
# 189               (drop, us)             (embodies, these)
# 190             (any, plans)          (every, opportunity)
# 191         (gravity, forms)             (internal, pitch)
# 192           (iphone, plus)           (these, principles)
# 193             (team, chat)              (ifttt, benerin)
# 194             (best, free)       (synchronize, customer)
# 195             (best, apps)            (feature, request)
# 196              (new, year)           (forward, hangouts)
# 197             (need, help)            (mobile, scanning)
# 198            (these, apps)                 (mail, chimp)
# 199    (communication, tool)               (stop, wasting)
#
#        Likelihood Ratio Test
# 0         (new, integration)
# 1           (revenue, leaks)
# 2         (biggest, revenue)
# 3            (social, media)
# 4            (live, without)
# 5       (million, customers)
# 6    (saleswings, unleashes)
# 7           (google, sheets)
# 8         (segment, workato)
# 9         (achieve, unicorn)
# 10         (unicorn, status)
# 11     (unleashes, powerful)
# 12        (marketing, tools)
# 13              (leaks, via)
# 14        (snaplogic, which)
# 15          (many, startups)
# 16          (these, leading)
# 17           (status, first)
# 18         (powerful, sales)
# 19       (flow, automations)
# 20               (axis, lms)
# 21            (wade, foster)
# 22       (leading, business)
# 23       (app, integrations)
# 24             (first, read)
# 25          (measuring, nps)
# 26              (work, flow)
# 27             (co, founder)
# 28        (fastest, growing)
# 29      (already, measuring)
# ..                       ...
# 170        (required, using)
# 171             (good, news)
# 172          (removed, when)
# 173             (feel, free)
# 174     (digital, downloads)
# 175            (tools, like)
# 176        (wordpress, site)
# 177       (lead, generation)
# 178       (mlsp, funnelizer)
# 179     (content, marketing)
# 180          (google, drive)
# 181  (application, security)
# 182               (drop, us)
# 183          (app, contacts)
# 184          (product, hunt)
# 185          (system, using)
# 186    (communication, tool)
# 187           (report, what)
# 188             (front, end)
# 189           (saves, hours)
# 190              (rd, party)
# 191           (brings, copy)
# 192      (automator, review)
# 193     (security, engineer)
# 194          (boring, tasks)
# 195         (instagram, app)
# 196        (small, business)
# 197             (cloud, app)
# 198            (remote, job)
# 199           (paste, magic)
#
# [200 rows x 5 columns]

# %%
bigrams_compare_2019
# Out:
#                      Frequency                           PMI  \
# 0                   (kph, mph)                 (dell, boomi)
# 1               (metres, feet)                (jenny, bloom)
# 2            (elevation, gain)          (storyteller, pairs)
# 3             (average, speed)             (jessica, greene)
# 4                  (km, miles)         (marcus, blankenship)
# 5                 (feet, link)             (highlight, reel)
# 6                   (done, km)         (keyword, extraction)
# 7                 (ride, done)            (decision, matrix)
# 8             (google, sheets)             (reel, delivered)
# 9           (new, integration)            (mlsp, funnelizer)
# 10           (using, mopinion)                    (sap, jam)
# 11             (social, media)           (takeaways, pushed)
# 12                (crm, using)  (celebrating, international)
# 13            (deliver, quick)              (san, francisco)
# 14         (web, applications)         (pomodoro, technique)
# 15           (integrate, data)             (engine, kabbage)
# 16     (integrations, between)               (bryan, helmig)
# 17                   (let, us)             (preview, toggle)
# 18               (would, love)              (rocket, genius)
# 19        (easy, integrations)           (blankenship, tune)
# 20              (various, web)      (computersociety, bryan)
# 21              (remote, work)               (seradio, host)
# 22              (open, source)              (joined, forces)
# 23                 (axis, lms)        (international, women)
# 24                (save, time)              (mental, health)
# 25             (contact, form)                (host, marcus)
# 26               (looks, like)                    (red, hat)
# 27          (fastest, growing)             (usa, salestools)
# 28           (integrate, axis)          (practice, ignition)
# 29               (best, tools)      (ruthlessly, prioritize)
# ..                         ...                           ...
# 170             (work, report)           (customer, loyalty)
# 171            (easier, click)         (speakers, announced)
# 172             (google, form)       (customer, storyteller)
# 173          (remote, working)            (pardot, buzzsumo)
# 174         (via, integrating)             (zendesk, ticket)
# 175          (without, coding)           (francisco, number)
# 176               (any, plans)          (paperform, process)
# 177               (last, week)         (online, whiteboards)
# 178           (tasks, without)             (marketer, needs)
# 179             (coming, soon)           (website, visitors)
# 180          (wordpress, form)              (deliver, quick)
# 181                  (e, mail)             (process, street)
# 182        (automation, tools)                   (rss, feed)
# 183            (google, forms)         (source, alternative)
# 184              (what, would)          (rt, jonathanaufray)
# 185        (certified, expert)      (automated, clickfunnel)
# 186        (small, businesses)                (rt, kevinlim)
# 187       (principles, thanks)          (aweber, integrates)
# 188          (embodies, these)                    (kph, mph)
# 189        (these, principles)          (successful, events)
# 190     (automate, repetitive)                (metres, feet)
# 191      (integrate, mopinion)              (leadfeeder, rt)
# 192       (create, meaningful)                  (long, term)
# 193           (events, create)                   (km, miles)
# 194       (successful, events)                  (conf, hear)
# 195      (experiences, people)          (customer, champion)
# 196         (remember, weemss)             (elevation, gain)
# 197         (always, remember)           (download, gravity)
# 198  (meaningful, experiences)                        (e, g)
# 199             (iphone, plus)          (password, security)
#
#                         T-test                Chi-Sq Test  \
# 0                   (kph, mph)                 (kph, mph)
# 1               (metres, feet)         (mlsp, funnelizer)
# 2                  (km, miles)             (metres, feet)
# 3            (elevation, gain)                (km, miles)
# 4             (average, speed)          (elevation, gain)
# 5                 (feet, link)           (traction, conf)
# 6                   (done, km)                (axis, lms)
# 7                 (ride, done)      (marcus, blankenship)
# 8             (google, sheets)           (average, speed)
# 9              (social, media)           (san, francisco)
# 10           (using, mopinion)            (bryan, helmig)
# 11                (crm, using)       (storyteller, pairs)
# 12          (new, integration)           (mental, health)
# 13            (deliver, quick)         (traffic, booster)
# 14         (web, applications)          (engine, kabbage)
# 15     (integrations, between)      (strategies, tactics)
# 16           (integrate, data)          (jessica, greene)
# 17                   (let, us)              (dell, boomi)
# 18              (various, web)             (jenny, bloom)
# 19        (easy, integrations)                  (gon, na)
# 20               (would, love)  (gainsight, surveymonkey)
# 21              (remote, work)            (social, media)
# 22              (open, source)      (industries, leaders)
# 23                 (axis, lms)  (booster, trafficbooster)
# 24             (contact, form)     (gmass, gmassforgmail)
# 25          (fastest, growing)      (keyword, extraction)
# 26                (save, time)           (joined, forces)
# 27               (looks, like)             (wade, foster)
# 28           (integrate, axis)                 (tray, io)
# 29               (best, tools)               (feet, link)
# ..                         ...                        ...
# 170                 (any, way)         (accessing, pages)
# 171               (last, week)         (senior, frontend)
# 172               (any, plans)      (empower, businesses)
# 173          (wordpress, form)       (every, opportunity)
# 174         (via, integrating)    (integrations, between)
# 175           (tasks, without)       (emotional, problem)
# 176          (remote, working)        (screen, recording)
# 177        (certified, expert)           (danish, number)
# 178                  (e, mail)         (evalato, through)
# 179        (small, businesses)      (developers, control)
# 180                (new, blog)        (highly, recommend)
# 181             (google, form)         (confusing, error)
# 182         (remember, weemss)          (embodies, these)
# 183  (meaningful, experiences)             (key, players)
# 184       (successful, events)      (project, management)
# 185          (embodies, these)          (microsoft, flow)
# 186         (always, remember)              (blown, away)
# 187        (these, principles)    (accounting, softwares)
# 188      (experiences, people)                  (got, ta)
# 189       (create, meaningful)      (scheduling, methods)
# 190       (principles, thanks)            (meeting, ends)
# 191            (google, forms)         (gmass, hootsuite)
# 192     (automate, repetitive)          (deadlines, less)
# 193           (events, create)                 (big, fan)
# 194                  (gon, na)         (gitlab, invision)
# 195             (wade, foster)       (paperform, process)
# 196            (update, chara)         (feature, request)
# 197             (iphone, plus)               (true, cost)
# 198      (integrate, mopinion)         (common, password)
# 199             (gmail, slack)           (text, analysis)
#
#          Likelihood Ratio Test
# 0                   (kph, mph)
# 1               (metres, feet)
# 2                  (km, miles)
# 3            (elevation, gain)
# 4             (average, speed)
# 5                 (feet, link)
# 6                   (done, km)
# 7                 (ride, done)
# 8             (google, sheets)
# 9              (social, media)
# 10            (deliver, quick)
# 11                 (axis, lms)
# 12              (open, source)
# 13         (web, applications)
# 14          (traffic, booster)
# 15          (fastest, growing)
# 16              (various, web)
# 17            (traction, conf)
# 18          (pardot, buzzsumo)
# 19        (hootsuite, traffic)
# 20           (integrate, axis)
# 21     (integrations, between)
# 22       (strategies, tactics)
# 23   (gainsight, surveymonkey)
# 24           (using, mopinion)
# 25         (buzzsumo, hubspot)
# 26       (industries, leaders)
# 27                   (let, us)
# 28       (source, alternative)
# 29        (easy, integrations)
# ..                         ...
# 170           (control, flows)
# 171       (create, meaningful)
# 172         (marketing, tools)
# 173       (customer, champion)
# 174          (engine, kabbage)
# 175        (tutorial, reveals)
# 176      (popular, automation)
# 177             (real, estate)
# 178            (early, access)
# 179               (link, ride)
# 180            (remote, teams)
# 181                  (got, ta)
# 182                 (big, fan)
# 183           (leadfeeder, rt)
# 184            (form, plugins)
# 185       (principles, thanks)
# 186            (device, magic)
# 187             (remote, team)
# 188           (creative, ways)
# 189           (text, analysis)
# 190            (flows, within)
# 191             (tettra, lets)
# 192              (need, every)
# 193               (last, week)
# 194             (last, chance)
# 195          (microsoft, flow)
# 196      (marcus, blankenship)
# 197               (every, day)
# 198           (tettra, tettra)
# 199             (hubspot, crm)
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Saving the bigrams comparison into Excel

# %%
list_sheet_titles = ["2016", "2017", "2018", "2019"]
list_dat_comparisons = [bigrams_compare_2016, bigrams_compare_2017, bigrams_compare_2018, bigrams_compare_2019]


with pd.ExcelWriter("./results/bigrams/compiled_bigrams.xlsx") as writer:
    for i in range(len(list_sheet_titles)):
    
        list_dat_comparisons[i].to_excel(writer, sheet_name = list_sheet_titles[i])
